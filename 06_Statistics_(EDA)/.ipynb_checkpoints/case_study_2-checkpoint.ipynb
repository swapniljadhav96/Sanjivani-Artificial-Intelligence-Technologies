# %% [markdown]
# # Case_study_2_Q2_b.csv

# %%
#case study 2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


#Load Q2.csv into a pandas dataFrame.
Q2 = pd.read_csv("C:/Data Science/3-Statistics/Q2_b.csv")

# %%
#shape of the dataset
print(Q2.shape)
# Out:
# (81, 3)

# %%
#column name of the dataset
Q2.columns
# Out:
# Index(['Unnamed: 0', 'SP', 'WT'], dtype='object')

# %%
Q2['SP'].value_counts()
# Out:
# 118.288996    4
# 105.461264    3
# 111.185353    3
# 119.105055    2
# 102.598513    2
#              ..
# 116.392639    1
# 115.748847    1
# 117.461264    1
# 117.105055    1
# 139.840817    1
# Name: SP, Length: 68, dtype: int64

# %%
Q2.dtypes
#Unnamed: 0      int64
#SP            float64
#WT            float64
#dtype: object
# Out:
# Unnamed: 0      int64
# SP            float64
# WT            float64
# dtype: object

# %%
Q2.isnull()
# Out:
#     Unnamed: 0     SP     WT
# 0        False  False  False
# 1        False  False  False
# 2        False  False  False
# 3        False  False  False
# 4        False  False  False
# ..         ...    ...    ...
# 76       False  False  False
# 77       False  False  False
# 78       False  False  False
# 79       False  False  False
# 80       False  False  False
#
# [81 rows x 3 columns]

# %%
# Scatterplot

Q2.plot(kind='scatter', x='SP', y="WT") ;
plt.show()

plt.hist(Q2.SP)

sns.FacetGrid(Q2, height=3) \
   .map(sns.distplot, "SP") \
   .add_legend();
plt.show();
# Out:
# C:\Users\suraj\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
import numpy as np

counts,bin_edges = np.histogram(Q2['SP'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(Q2['SP'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);

plt.show();
# Out:
# [0.09876543 0.14814815 0.39506173 0.12345679 0.12345679 0.02469136
#  0.01234568 0.02469136 0.01234568 0.03703704]
# [ 99.56490661 106.56826723 113.57162785 120.57498847 127.57834909
#  134.58170971 141.58507032 148.58843094 155.59179156 162.59515218
#  169.5985128 ]

# %%
# Inference
# PDF - Probablity Density function
# df will 0.04 to 0.10 from 5.0 to 25.0
# 

sns.boxplot(Q2.SP)
plt.show()

# %%
sns.boxplot(Q2.WT)
plt.show()

# %%
Q2.mean()
# Out:
# Unnamed: 0     41.000000
# SP            121.540272
# WT             32.412577
# dtype: float64

# %%
print("\nStd-dev:");
print(np.std(Q2["SP"]))
print(np.std(Q2["WT"]))
# Out:
# Std-dev:
# 14.093620008403487
# 7.446417424384509

# %%
# skewness
from scipy.stats import skew
from scipy.stats import kurtosis



sp_lst=Q2['SP'].tolist()
print(skew(sp_lst))
print(kurtosis(sp_lst,axis=0,bias=True))


lst=Q2['SP'].tolist()
print(skew(lst))

print(kurtosis(lst,axis=0,bias=True))
# Out:
# 1.5814536794423764
# 2.7235214865269244
# 1.5814536794423764
# 2.7235214865269244

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(Q2["SP"]))
#Median with an outlier
print(np.median(np.append(Q2["SP"],50)));
# Out:
# Medians:
# 118.2086984
# 117.93862405
